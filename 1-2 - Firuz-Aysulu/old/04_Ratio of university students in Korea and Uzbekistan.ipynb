# %%
import matplotlib.pyplot as plt

import numpy as np

import pandas as pd

from matplotlib import ticker

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

data_rsku = pd.read_csv("04_korea.csv", sep = ";")
data_rsku.head(999)
# Out:
#     Year      Kor     Uzb   Uzb_per    Kor_per
# 0   2010  1995000  274500  3.200000  -6.800000
# 1   2011  2070000  253000  3.759398  -7.832423
# 2   2012  2100000  258300  1.449275   2.094862
# 3   2013  2130000  259100  1.428571   0.309717
# 4   2014  2130000  261500  0.000000   0.926283
# 5   2015  2110000  264300 -0.938967   1.070746
# 6   2016  2080000  268300 -1.421801   1.513432
# 7   2017  2050000  297800 -1.442308  10.995155
# 8   2018  2030000  360200 -0.975610  20.953660
# 9   2019  2000000  441000 -1.477833  22.431982
# 10  2020  1980000  590077 -1.000000  33.804308

# %%
# Graph - 1 - Name

plt.figure(figsize = (11.5, 5), dpi = 300)

plt.plot(data_rsku.Year, data_rsku.Kor, "o-", label='Korea students', color='greenyellow')
plt.plot(data_rsku.Year, data_rsku.Uzb, "o-", label='Uzbekistan students', color='darkorange')

plt.title('Comparison of number of students in Korea and Uzbekistan', fontdict = font1, color='green')
plt.xlabel('Years', fontdict = font2)
plt.ylabel('Number of students', fontdict = font2)


plt.legend(loc='center')
plt.grid(axis = 'both', color = 'lightblue', linestyle = ':', linewidth = 0.5)
plt.tick_params(axis ='both', which ='major', labelsize = 10, pad = 10, colors ='g')
plt.show()

# Graph - 2 - Name
        
plt.figure(figsize = (11.5, 5), dpi = 300)
plt.plot(data_rsku.Year, data_rsku.Uzb_per, "o-", label='Uzbekistan students',color='greenyellow')
plt.plot(data_rsku.Year, data_rsku.Kor_per, "o-", label='Korean students', color='darkorange')

plt.title('Percentage  from 2010 to 2020', fontdict = font1,color='green')
plt.xlabel('Years', fontdict = font2)
plt.ylabel('Percentage', fontdict = font2)

plt.legend()
plt.grid(axis = 'both', color = 'lightblue', linestyle = ':', linewidth = 0.5)
plt.tick_params(axis ='both', which ='major', labelsize = 10, pad = 10, colors ='g')
plt.show()
