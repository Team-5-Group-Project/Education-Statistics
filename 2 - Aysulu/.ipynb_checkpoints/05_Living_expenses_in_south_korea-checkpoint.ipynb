# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as py

pd.read_csv("05_living_expenses_in_korea.csv", sep = ";")
liv = pd.read_csv("05_living_expenses_in_korea.csv", sep = ";")

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize = (9,4), dpi = 100)

plt.bar(liv.type_of_expenses, liv.cost_in_usd / 6**4) #put value labels and work on the design
plt.title("Monthly living expenses in South Korea")
plt.xlabel("Type of expenses")
plt.ylabel("Cost in USD")

plt.show()
